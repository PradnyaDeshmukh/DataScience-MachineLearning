# %%
# pandas, numpy and sklearn
# pip install pandas, sklearn

import pandas as pd  # pd is an object of pandas
dataset = pd.read_csv("temperatures.csv")
print(dataset.shape)
dataset.head()
# Out:
# (117, 18)
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
X = dataset[['YEAR','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']]
y = dataset['ANNUAL']

# # Split the dataset into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state = 42)

# # # Building the multiple linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
print(model.intercept_)
print(model.coef_)

coeff = pd.DataFrame(model.coef_, columns = ['Coefficient'])

predict = model.predict(X_test)

import matplotlib.pyplot as plt
plt.scatter(y_test, predict)
plt.show()
from sklearn import metrics
print('MAE', metrics.mean_absolute_error(y_test,predict))
print('MSE', metrics.mean_squared_error(y_test,predict))
# Out:
# -0.130177438386621
# [0.00046645 0.08899711 0.08379754 0.07615083 0.08819696 0.06056362
#  0.08373993 0.05646082 0.08951923 0.09255852 0.11578739 0.04815461
#  0.09210932]
# MAE 0.027534750775806315
# MSE 0.0019676419505715663
